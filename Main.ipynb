# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# data load
df = pd.read_csv('Data_Polis.csv')

print("Five upper row")
display(df.head()) 

print("\ndata info")
print(df.info())
# Out:
# Five upper row
#   Nomor Polis Plan Code Gender  Tanggal Lahir  Tanggal Efektif Polis Domisili
# 0    POL-0001     M-003      M       19640811               20140603  JAKARTA
# 1    POL-0002     M-003      M       19710730               20140603  JAKARTA
# 2    POL-0003     M-001      M       19790821               20160808  JAKARTA
# 3    POL-0004     M-003      M       20140724               20160811  JAKARTA
# 4    POL-0005     M-001      F       19810114               20150828  JAKARTA
# data info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4096 entries, 0 to 4095
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Nomor Polis            4096 non-null   object
#  1   Plan Code              4096 non-null   object
#  2   Gender                 4096 non-null   object
#  3   Tanggal Lahir          4096 non-null   int64
#  4   Tanggal Efektif Polis  4096 non-null   int64
# ...

# %%
d2 = pd.read_csv('Data_Klaim.csv')

print("\nFive upper row")
display(d2.head())

print("\ndata info")
print(d2.info())
# Out:
# Five upper row
#    Claim ID Nomor Polis Reimburse/Cashless Inpatient/Outpatient ICD Diagnosis  \
# 0  C-0001-M    POL-0176                  R                   OP           C50
# 1  C-0002-M    POL-3288                  R                   OP           C34
# 2  C-0003-M    POL-1786                  R                   OP         C18.9
# 3  C-0004-M    POL-1786                  R                   OP           C34
# 4  C-0005-M    POL-2778                  R                   OP           C50
#
#                            ICD Description Status Klaim  \
# 0             MALIGNANT NEOPLASM OF BREAST         PAID
# 1  MALIGNANT NEOPLASM OF BRONCHUS AND LUNG         PAID
# 2   MALIGNANT NEOPLASM, COLON, UNSPECIFIED         PAID
# 3  MALIGNANT NEOPLASM OF BRONCHUS AND LUNG         PAID
# 4             MALIGNANT NEOPLASM OF BREAST         PAID
#
#   Tanggal Pembayaran Klaim Tanggal Pasien Masuk RS Tanggal Pasien Keluar RS  \
# ...

# %%
d3 = pd.read_csv('sample_submission.csv')
print("\nFive upper row")
display(d3.head())
print("\ndata info")
print(d3.info())
# Out:
# Five upper row
#                         id  value
# 0  2025_08_Claim_Frequency      0
# 1   2025_08_Claim_Severity      0
# 2      2025_08_Total_Claim      0
# 3  2025_09_Claim_Frequency      0
# 4   2025_09_Claim_Severity      0
# data info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      15 non-null     object
#  1   value   15 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 372.0+ bytes
# None

# %%
# missing value check
print("\nMissing value")
missing_values = df.isnull().sum()
print(missing_values[missing_values > 0]) 

plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Mising Values Heatmap')
plt.show()
# Out:
# Missing value
# Series([], dtype: int64)

# %%
# missing value check
print("\nMissing value")
missing_values = d2.isnull().sum()
print(missing_values[missing_values > 0]) 

plt.figure(figsize=(10, 6))
sns.heatmap(d2.isnull(), cbar=False, cmap='viridis')
plt.title('Mising Values Heatmap')
plt.show()
# Out:
# Missing value
# Inpatient/Outpatient        37
# ICD Diagnosis                6
# ICD Description              6
# Tanggal Pembayaran Klaim    37
# Lokasi RS                    7
# dtype: int64

# %%
# duplicate check
print(f"\nSum of duplicate rows : {df.duplicated().sum()}")

df.drop_duplicates(inplace=True)

print("\nStatistical Summary")
display(df.describe())
# Out:
# Sum of duplicate rows : 0
#
# Statistical Summary
#        Tanggal Lahir  Tanggal Efektif Polis
# count   4.096000e+03           4.096000e+03
# mean    1.972234e+07           2.014666e+07
# std     1.718649e+05           1.742636e+04
# min     1.933101e+07           2.011120e+07
# 25%     1.959102e+07           2.013083e+07
# 50%     1.970033e+07           2.015032e+07
# 75%     1.982111e+07           2.016081e+07
# max     2.017111e+07           2.018022e+07

# %%
# duplicate check
print(f"\nSum of duplicate rows : {d2.duplicated().sum()}")

print("\nStatistical Summary")
display(d2.describe())
# Out:
# Sum of duplicate rows : 0
#
# Statistical Summary
#        Nominal Klaim Yang Disetujui  Nominal Biaya RS Yang Terjadi
# count                  4.627000e+03                   4.627000e+03
# mean                   5.502892e+07                   5.994940e+07
# std                    1.319527e+08                   1.597838e+08
# min                    0.000000e+00                   0.000000e+00
# 25%                    2.274009e+06                   2.720210e+06
# 50%                    1.446790e+07                   1.587100e+07
# 75%                    5.107209e+07                   5.423067e+07
# max                    2.197500e+09                   3.892810e+09
