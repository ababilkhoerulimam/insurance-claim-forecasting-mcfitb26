# %%
import pandas as pd

df1 = pd.read_csv("submission_prophet_early.csv")
df2 = pd.read_csv("submission_prophet2.csv")

print((df1 == df2).all())
print((df1["value"] - df2["value"]).abs().max())
# Out:
# id       True
# value    True
# dtype: bool
# 0.0
